# %% [markdown]
# #### How ?
# - How to Read DICOM files
# - How to get Numpy array of DICOM image
# - How to plot using matplotlib

# %%
import pydicom
from matplotlib import pyplot as plt

# %%
d_file = pydicom.dcmread("Image-105.dcm")
print(np.sum(d_file.pixel_array))
plt.imshow(d_file.pixel_array, cmap="gray")
# Out:
# 44386311

# %%
# Patient ID - also stores in Image Information
print(d_file.PatientID)
# Out:
# 00000

# %%
# 2nd way to read
dicom = pydicom.read_file('Image-105.dcm')
plt.imshow(dicom.pixel_array, cmap='gray')
print(dicom.pixel_array.sum())
# Out:
# 44386311

# %%
d_file = dicom.dcmread("Image-1.dcm")
print(np.sum(d_file.pixel_array))
plt.imshow(d_file.pixel_array, cmap="gray")
# Out:
# 0

# %% [markdown]
# #### How to import Kaggle Data into Colab?
# - How to Import Kaggle Dataset directly into Colab
# - How to unzip it?

# %% [markdown]
# Create a JSON key and upload to Colab
#
# Profile ==> Account ==> API (Create New API Token) ==> kaggle.json will be downloaded

# %% [markdown]
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c rsna-miccai-brain-tumor-radiogenomic-classification
# # or
# !kaggle datasets download -c rsna-miccai-brain-tumor-radiogenomic-classification  (if dataset does not belong to competition)
# !unzip <name-of-file>

# %% [markdown]
# #### How to directly work in Kaggle Notebook ?
# - How to create new notebook?
# - How to add competion data?
# - Location of data?

# %% [markdown]
# Code
# New Notebook
# Add Data ==> Select Competition ==> Data will be added in /kaggle/input/<competion-name>
